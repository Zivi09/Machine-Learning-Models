# %% [markdown]
# 1.  Type of Algorithm : Linear Regression
# 2.  Type of ML problem it solves : regresion
# 3.  Training Principal of Algorithm : To find a regressor linear line such that
#     all of the data points are nearest to the line. which means the distance of each data point to this line is minimum. The target of simple linear regression is to find the coefficient to produce the best fit line
# 4.  Parameters:
# 5.  Hyperparameter:simple linear regresion
#       independent variable x
#       dependent variable y
#       coefficient beta and alpha
#       feature is called as independent variable
#       target is called as dependent variable
#       y=alpha x +beta
#       y= beta x+beta
#       y= mx +c.

# %% [markdown]
# Equation
# y = m n + c
# n  = feature / IV
# y = target /DV
# coef = m,c

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/content/META.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  28/10/2021  312.989990  325.519989  308.109985  316.920013  316.584106
# 1  29/10/2021  320.190002  326.000000  319.600006  323.570007  323.227051
# 2  01/11/2021  326.040009  333.450012  326.000000  329.980011  329.630280
# 3  02/11/2021  331.380005  334.790009  323.799988  328.079987  327.732269
# 4  03/11/2021  327.489990  332.149994  323.200012  331.619995  331.268524
#
#      Volume
# 0  50806800
# 1  37059400
# 2  31518900
# 3  28353000
# 4  20786500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 633 entries, 0 to 632
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       633 non-null    object
#  1   Open       633 non-null    float64
#  2   High       633 non-null    float64
#  3   Low        633 non-null    float64
#  4   Close      633 non-null    float64
#  5   Adj Close  633 non-null    float64
#  6   Volume     633 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 34.7+ KB

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
X = df['High'].values.reshape(-1, 1)
y = df['Volume'].values.reshape(-1, 1)

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
X_range = np.arange(min(X), max(X), 0.1)
y_pred = model.predict(X_range.reshape(-1, 1))
# Out:
# <ipython-input-45-3e5e35613e29>:1: DeprecationWarning:
#
# Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)

# %%
import plotly.express as px
import plotly.graph_objects as go
fig = px.scatter(df, x='High', y='Volume')
fig.add_trace(go.Scatter(x=X_range, y=y_pred, mode='lines'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from matplotlib import pyplot as plt
df['High'].plot(kind='hist')
plt.gca().spines[['top','right']].set_visible(False)

# %%
plt.title('High Stock Distrubition plot')
sns.distplot(df['High'])
plt.show()
# Out:
# <ipython-input-51-cd2e9a205bee>:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
plt.scatter(df['High'], df['Volume'], color = 'lightcoral')
plt.title('Volume  vs High Stock ')
plt.xlabel('High Stock Buyed ')
plt.ylabel('Volume of stock ')
plt.box(False)
plt.show()

# %%
print(f'Coeficient : {model.coef_}')
print(f'Intercept : {model.intercept_}')
# Out:
# Coeficient : [[-64474.10195495]]
# Intercept : [44813794.42560808]
