# %% [markdown]
# # **Simple Linear Regression**

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression

# %% [markdown]
# **Load the dataset**

# %%
# Get dataset
df_sal = pd.read_csv('/content/med-insurance.csv')
df_sal.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# **Data analysis**

# %%
# Describe data
df_sal.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_27['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28['bmi'].plot(kind='hist', bins=20, title='bmi')
# ...

# %% [markdown]
# **Data Distribution Plot**

# %%
# Data distribution
plt.title('Age Distribution Plot')
sns.distplot(df_sal['age'])
plt.show()
# Out:
# /tmp/ipython-input-82593181.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_sal['age'])

# %% [markdown]
# **check the relationship between Age and Expense**

# %%
plt.scatter(df_sal['age'], df_sal['expenses'], color='lightcoral')
plt.title('Age vs Medical Expenses')
plt.xlabel('Age')
plt.ylabel('Expenses')
plt.box(False)
plt.show()

# %% [markdown]
# From the scatter plot, we can see that medical expenses generally increase with age. Older individuals tend to incur higher medical costs compared to younger individuals. This shows a positive linear relationship between age and medical expenses.

# %% [markdown]
# **Split the dataset into dependent/independent variables**
# Experience (X) is the independent variable
#
#
# Salary (y) is dependent on experience

# %%
# Encode 'sex' column into numerical (0 for female, 1 for male)
df_sal['sex'] = df_sal['sex'].map({'female': 0, 'male': 1})

# Splitting variables
X = df_sal[['age']]  # independent variables: 'age' and encoded 'sex'
y = df_sal['expenses']  # dependent variable: 'expenses'

# %% [markdown]
# **Split data into Train/Test sets**
#
#
# Further, split your data into training (80%) and test (20%) sets using train_test_split

# %%
# Splitting dataset into test/train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# **Train the regression model**
#
# Pass the X_train and y_train data into the regressor model by regressor.fit to train the model with our training data

# %%
# Regressor model
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Prediction result
y_pred_test = regressor.predict(X_test)     # predicted value of y_test
y_pred_train = regressor.predict(X_train)   # predicted value of y_train

# %%
# Prediction on training set
plt.scatter(X_train, y_train, color = 'lightcoral')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Salary vs Experience (Training Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.box(False)
plt.show()

# %% [markdown]
# **Plot test set data vs predictions**
#
#
# Secondly, we plot the result of test sets (X_test, y_test) with X_train and predicted value of y_train (regressor.predict(X_train))

# %%
# Prediction on test set
plt.scatter(X_test, y_test, color = 'lightcoral')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Salary vs Experience (Test Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.box(False)
plt.show()

# %% [markdown]
# Linear equation y = mx + c, we can also get the c (y-intercept) and m (slope/coefficient) from the regressor model.
# The scatter plot shows the actual medical expenses for the test dataset, while the regression line represents the predicted expenses generated by the model. If the points lie close to the line, the prediction accuracy is high. In this case, some points are near the line while others are scattered away, indicating that age alone does not fully determine medical expenses, although there is still a positive trend. Therefore, the model captures the general pattern but is not perfectly accurate.

# %%
# Regressor coefficients and intercept
print(f'Coefficient: {regressor.coef_}')
print(f'Intercept: {regressor.intercept_}')
# Out:
# Coefficient: [238.37156754]
# Intercept: 3882.858927951136
